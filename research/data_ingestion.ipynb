# %%
import os

# %%
# %pwd
# Out:
# '/Users/mudassirhussain/code/projects/text-proj/text-summarizer/research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# '/Users/mudassirhussain/code/projects/text-proj/text-summarizer'
